# %% [markdown]
# # Лабораторная работа 1

# %% [markdown]
# 1) Классификация данных методом k ближайших соседей ( kNN)
#
# 2) Классификация данных методом опорных векторов (SVM)
#
# 3) Построение softmax-классификатора
#
# Вариант 1: задания 1 и 2 на наборе данных CIFAR-10
#
# Вариант 2: задания 1 и 2 на наборе данных MNIST
#
# Вариант 3: задания 1 и 3 на наборе данных CIFAR-10
#
# Вариант 4: задания 1 и 3 на наборе данных MNIST

# %% [markdown]
# Лабораторные работы можно выполнять с использованием сервиса Google Colaboratory (https://medium.com/deep-learning-turkey/google-colab-free-gpu-tutorial-e113627b9f5d) или на локальном компьютере.

# %% [markdown]
# ## 1. Классификация данных методом k ближайших соседей ( kNN)

# %%
import random
import numpy as np
import matplotlib.pyplot as plt
from scripts.data_utils import load_CIFAR10


# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) 
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# %% [markdown]
# 1.1 Скачайте данные в соответсвии с заданием.
#
# CIFAR-10 по ссылке https://www.cs.toronto.edu/~kriz/cifar.html
# или используйте  команду !bash get_datasets.sh (google colab, local ubuntu)
#
# MNIST
# sklearn.datasets import load_digits
# digits = load_digits()

# %%
cifar10_dir = 'scripts/datasets/cifar-10-batches-py'

try:
   del X_train, y_train
   del X_test, y_test
   print('Clear previously loaded data.')
except:
   pass

X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)

print('Training data shape: ', X_train.shape)
print('Training labels shape: ', y_train.shape)
print('Test data shape: ', X_test.shape)
print('Test labels shape: ', y_test.shape)
# Out:
# Training data shape:  (50000, 32, 32, 3)
# Training labels shape:  (50000,)
# Test data shape:  (10000, 32, 32, 3)
# Test labels shape:  (10000,)

# %% [markdown]
# 1.2 Выведите несколько примеров изображений из обучающей выборки для каждого класса.

# %%
# Функция для вывода изображений по классам
def plot_images(X, y, class_names):
    num_classes = len(class_names)  # Количество классов
    samples_per_class = 5  # Количество изображений для вывода на каждый класс

    fig, axes = plt.subplots(samples_per_class, num_classes, figsize=(15, 10))
    fig.subplots_adjust(hspace=0.6, wspace=0.1)

    for class_idx, class_name in enumerate(class_names):
        idxs = np.flatnonzero(y == class_idx)  # Индексы изображений текущего класса
        idxs = np.random.choice(idxs, samples_per_class, replace=False)  # Случайный выбор изображений

        for img_idx, idx in enumerate(idxs):
            ax = axes[img_idx, class_idx]  # Определение позиции для текущего изображения
            ax.imshow(X[idx].astype('uint8'))  # Отображение изображения
            ax.axis('off')  # Убрать оси

            if not img_idx:  # Заголовок только у первого изображения в каждой колонке
                ax.set_title(class_name)

# Названия классов для CIFAR-10
classes_cifar10 = ['airplane', 'automobile', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']

# Вывод изображений
plot_images(X_train, y_train, classes_cifar10)
plt.show()

# %% [markdown]
# 1.3 Разделите данные на обучающую и тестовую выборки (X_train, y_train, X_test, y_test). Преобразуйте каждое изображение в одномерный массив.

# %%
# Разделение данных на обучающую и тестовую выборки (X_train, y_train, X_test, y_test)
# X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir) - уже было сделано

# Преобразование каждого изображения в одномерный массив
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

print('Размерность обучающей выборки после преобразования:', X_train_flat.shape)
print('Размерность тестовой выборки после преобразования:', X_test_flat.shape)
# Out:
# Размерность обучающей выборки после преобразования: (50000, 3072)
# Размерность тестовой выборки после преобразования: (10000, 3072)

# %% [markdown]
# 1.4 Напишите реализацию классификатора в скрипте /classifiers/k_nearest_neighbor.py и обучите его на сформированной выборке.

# %%
from scripts.classifiers import KNearestNeighbor

classifier = KNearestNeighbor()
classifier.train(X_train_flat, y_train)  # Переформатируем массив для совместимости

# %% [markdown]
# 1.5 Выполните классификацию на тестовой выборке

# %%
num_test_samples = 500

# Убедимся, что количество запрошенных образцов не превышает размер массива
num_test_samples = min(num_test_samples, X_test_flat.shape[0])

# Случайно выбираем индексы изображений для тестовой выборки
test_sample_idxs = np.random.choice(X_test_flat.shape[0], num_test_samples, replace=False)

# Выбираем соответствующие изображения и метки для тестовой выборки
X_test_subsample = X_test_flat[test_sample_idxs]
y_test_subsample = y_test[test_sample_idxs]

# Выполняем классификацию на уменьшенной тестовой выборке
y_test_pred_subsample = classifier.predict(X_test_subsample)

# %% [markdown]
# 1.6 Визуализируйте матрицу расстояний для каждого изображения из тестовой выборки до изображений из обучающей выборки.

# %%
# Вычисляем матрицу расстояний между изображениями из тестовой и обучающей выборок
dists = classifier.compute_distances_no_loops(X_test_subsample)

# Визуализация матрицы расстояний
plt.figure(figsize=(10, 8))
plt.imshow(dists, aspect='auto', interpolation='none')
plt.colorbar()
plt.title('Матрица расстояний')
plt.xlabel('Индексы обучающей выборки')
plt.ylabel('Индексы тестовой выборки')
plt.show()

# %% [markdown]
# 1.7 Посчитайте долю правильно классифицированных изображений из тестовой выборки.

# %%
# Оцениваем точность классификации
accuracy_subsample = np.mean(y_test_pred_subsample == y_test_subsample)
print(f'Точность: {accuracy_subsample:.2f}')
# Out:
# Точность: 0.38

# %% [markdown]
# 1.8 Постройте график зависимости доли правильно классифицированных изображений от числа соседей, используемых при классификации.

# %%
# Задаем диапазон значений k
k_values = range(1, 11)
accuracies = []

for k in k_values:
    # Создание и инициализация KNN классификатора
    classifier = KNearestNeighbor()
    classifier.train(X_train_flat, y_train)
    y_test_pred_subsample_k = classifier.predict(X_test_subsample, k=k)
    
    # Вычисляем и сохраняем точность
    accuracy = np.mean(y_test_pred_subsample_k == y_test_subsample)
    accuracies.append(accuracy)

# Визуализация результатов
plt.plot(k_values, accuracies, marker='o')
plt.xlabel('Число соседей k')
plt.ylabel('Точность')
plt.title('Зависимость точности от числа соседей k')
plt.grid(True)
plt.show()

# %% [markdown]
# 1.9 Выберите лучшее значение параметра k на основе кросс-валидации.

# %%
from sklearn.model_selection import KFold
import numpy as np

# Инициализируем KFold
kf = KFold(n_splits=5, random_state=None, shuffle=True)

# Для сохранения средней точности для каждого k
mean_accuracies = []

for k in k_values:  # k_values - список значений k, который вы тестировали ранее
    accuracies = []
    
    for train_index, val_index in kf.split(X_test_subsample):
        X_train_k, X_val_k = X_test_subsample[train_index], X_test_subsample[val_index]
        y_train_k, y_val_k = y_train[train_index], y_train[val_index]
        
        # Создаем и обучаем классификатор на текущем разделении
        classifier = KNearestNeighbor()
        classifier.train(X_train_k, y_train_k)
        
        # Предсказываем и вычисляем точность на валидационном наборе
        y_pred = classifier.predict(X_val_k, k=k)
        accuracy = np.mean(y_pred == y_val_k)
        accuracies.append(accuracy)
    
    # Сохраняем среднюю точность для текущего k
    mean_accuracy = np.mean(accuracies)
    mean_accuracies.append(mean_accuracy)
    
# Находим лучшее K
best_k = k_values[np.argmax(mean_accuracies)]
best_accuracy = max(mean_accuracies)  # Вычисляем максимальную точность

print("Лучшее значение k:", best_k)
print("Лучшая точность:", best_accuracy)
# Out:
# Лучшее значение k: 8
# Лучшая точность: 0.11200000000000002

# %% [markdown]
# 1.10 Переобучите и протестируйте классификатор с использованием выбранного значения k.

# %%
# Переобучение классификатора с использованием лучшего значения k
best_k_classifier = KNearestNeighbor()
best_k_classifier.train(X_train_flat, y_train)

# Прогнозирование меток классов на тестовом наборе
y_test_pred = best_k_classifier.predict(X_test_subsample, k=best_k)

# Оценка точности классификатора на тестовом наборе
test_accuracy = np.mean(y_test_pred == y_test_subsample)
print(f'Точность классификатора с k={best_k} на тестовом наборе: {test_accuracy:.2f}')
# Out:
# Точность классификатора с k=8 на тестовом наборе: 0.34

# %% [markdown]
# 1.11 Сделайте выводы по результатам 1 части задания.

# %% [markdown]
# В первой части задачи акцент был сделан на изучение основ нейронных сетей и их тренировочный процесс. Обсуждались темы, связанные с линейными классификаторами, функциями потерь и методами оптимизации параметров сети, такими как градиентный спуск. Было показано, как выбор функции потерь, таких как SVM и Softmax, может влиять на тренировку модели.
#
# Основные выводы:
#
# Значение выбора подходящей функции потерь: Различные функции потерь лучше работают для разных задач и могут оказывать значительное влияние на качество обучения модели.
# Эффективность градиентного спуска: Этот метод оптимизации параметров модели является эффективным, но для достижения наилучших результатов требуется тщательный подбор скорости обучения и других гиперпараметров.
# Применимость линейных классификаторов: Они могут быть успешно использованы для решения задач классификации, хотя их применение ограничено возможностью линейной разделимости классов.

# %% [markdown]
# ## 2.  Классификация данных методом опорных векторов (SVM)

# %% [markdown]
# 2.1 Разделите данные на обучающую, тестовую и валидационную выборки. Преобразуйте каждое изображение в одномерный массив. Выведите размеры выборок.

# %%
from sklearn.model_selection import train_test_split

# Преобразование каждого изображения из обучающего и тестового наборов в одномерный массив
X_train_flat = X_train.reshape(X_train.shape[0], -1)
X_test_flat = X_test.reshape(X_test.shape[0], -1)

# Разделение обучающего набора на новый обучающий и валидационный наборы
X_train_flat, X_val_flat, y_train, y_val = train_test_split(X_train_flat, y_train, test_size=0.2, random_state=42)

print('Размеры выборок:')
print('Обучающая выборка:', X_train_flat.shape)
print('Тестовая выборка:', X_test_flat.shape)
print('Валидационная выборка:', X_val_flat.shape)
# Out:
# Размеры выборок:
# Обучающая выборка: (40000, 3072)
# Тестовая выборка: (10000, 3072)
# Валидационная выборка: (10000, 3072)

# %% [markdown]
# 2.2 Проведите предварительную обработку данных, путем вычитания среднего изображения, рассчитанного по обучающей выборке.
#
# 2.3 Чтобы далее не учитывать смещение (свободный член b), добавьте дополнительную размерность к массиву дынных и заполните ее 1.

# %%
# Вычисление среднего значения по каждому пикселю из обучающего набора
mean_image = np.mean(X_train_flat, axis=0)

# Визуализация среднего изображения
plt.figure(figsize=(4, 4))
# Адаптация формата изображения для корректной визуализации
plt.imshow(mean_image.reshape((32, 32, 3)).astype('uint8'))
plt.title("Среднее изображение")
plt.show()

# Нормализация данных путем вычитания среднего изображения из всех выборок
X_train_flat -= mean_image
X_val_flat -= mean_image
X_test_flat -= mean_image

# Добавление единичной колонки к данным для учета смещения в линейных моделях
X_train_flat = np.hstack([X_train_flat, np.ones((X_train_flat.shape[0], 1))])
X_val_flat = np.hstack([X_val_flat, np.ones((X_val_flat.shape[0], 1))])
X_test_flat = np.hstack([X_test_flat, np.ones((X_test_flat.shape[0], 1))])

# Вывод размеров обработанных массивов данных
print("Размеры обработанных массивов данных:")
print("Тренировочные данные:", X_train_flat.shape)
print("Валидационные данные:", X_val_flat.shape)
print("Тестовые данные:", X_test_flat.shape)
# Out:
# Размеры обработанных массивов данных:
# Тренировочные данные: (40000, 3073)
# Валидационные данные: (10000, 3073)
# Тестовые данные: (10000, 3073)

# %% [markdown]
# 2.4 Реализуйте loss-функции в scripts/classifiers/linear_svm.py

# %%
from scripts.classifiers.linear_svm import svm_loss_naive, svm_loss_vectorized
import time

# Выберем случайное подмножество из обучающего набора для разработки
num_dev_samples = 500
mask = np.random.choice(X_train_flat.shape[0], num_dev_samples, replace=False)
X_dev = X_train_flat[mask]
y_dev = y_train[mask]

W = np.random.randn(3073, 10) * 0.0001 

loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.000005)
print('loss: %f' % (loss, ))
# Out:
# loss: 8.675925

# %% [markdown]
# 2.5 Убедитесь, что вы верно реализовали расчет градиента, сравнив с реализацией численными методами (код приведен ниже).

# %%
loss, grad = svm_loss_naive(W, X_dev, y_dev, 0.0)

from scripts.gradient_check import grad_check_sparse
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad)


loss, grad = svm_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: svm_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad)
# Out:
# numerical: -22.900573 analytic: -22.900573, relative error: 5.473912e-12
# numerical: -7.291593 analytic: -7.314912, relative error: 1.596490e-03
# numerical: -9.571129 analytic: -9.571129, relative error: 1.966345e-11
# numerical: 26.255462 analytic: 26.255462, relative error: 2.173565e-11
# numerical: -18.300716 analytic: -18.300716, relative error: 1.403442e-11
# numerical: -28.246418 analytic: -28.232593, relative error: 2.447789e-04
# numerical: 6.569870 analytic: 6.569870, relative error: 6.105057e-11
# numerical: -14.231857 analytic: -14.231857, relative error: 4.719475e-11
# numerical: -12.084120 analytic: -12.084120, relative error: 1.878651e-13
# numerical: 17.665555 analytic: 17.665555, relative error: 1.277619e-11
# numerical: -37.277772 analytic: -37.284517, relative error: 9.046185e-05
# numerical: -0.772820 analytic: -0.772820, relative error: 3.381213e-10
# numerical: 5.742003 analytic: 5.742003, relative error: 3.262314e-11
# numerical: -1.232391 analytic: -1.232391, relative error: 1.558053e-11
# numerical: 12.405339 analytic: 12.405339, relative error: 1.304846e-12
# numerical: 26.300839 analytic: 26.300839, relative error: 7.826865e-12
# numerical: 15.612787 analytic: 15.612787, relative error: 3.225230e-11
# numerical: 3.381169 analytic: 3.381169, relative error: 2.666057e-11
# numerical: 5.854345 analytic: 5.854345, relative error: 7.626233e-11
# numerical: 12.628401 analytic: 12.628401, relative error: 3.698188e-12

# %% [markdown]
# 2.6 Сравните svm_loss_naive и svm_loss_vectorized реализации

# %%
tic = time.time()
_, grad_naive = svm_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Naive loss and gradient: computed in %fs' % (toc - tic))

tic = time.time()
_, grad_vectorized = svm_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('Vectorized loss and gradient: computed in %fs' % (toc - tic))

difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('difference: %f' % difference)
# Out:
# Naive loss and gradient: computed in 0.164734s
# Vectorized loss and gradient: computed in 0.049372s
# difference: 0.000000

# %% [markdown]
# 2.7 Реализуйте стохастический градиентный спуск в /classifiers/linear_classifier.py . Реализуйте методы train() и predict() и запустите следующий код

# %%
from scripts.classifiers import LinearSVM
svm = LinearSVM()
tic = time.time()
loss_hist = svm.train(X_dev, y_dev, learning_rate=1e-7, reg=2.5e4,
                      num_iters=1500, verbose=True)
toc = time.time()
print('That took %fs' % (toc - tic))
# Out:
# iteration 0 / 1500: loss 797.286242
# iteration 100 / 1500: loss 286.837116
# iteration 200 / 1500: loss 106.161121
# iteration 300 / 1500: loss 40.703896
# iteration 400 / 1500: loss 16.641687
# iteration 500 / 1500: loss 8.031545
# iteration 600 / 1500: loss 4.958177
# iteration 700 / 1500: loss 3.674134
# iteration 800 / 1500: loss 3.257183
# iteration 900 / 1500: loss 3.057250
# iteration 1000 / 1500: loss 3.228233
# iteration 1100 / 1500: loss 2.856043
# iteration 1200 / 1500: loss 3.016594
# iteration 1300 / 1500: loss 3.077730
# iteration 1400 / 1500: loss 2.759305
# That took 8.389139s

# %%
y_train_pred = svm.predict(X_train_flat)
print('training accuracy: %f' % (np.mean(y_train == y_train_pred), ))
y_val_pred = svm.predict(X_val_flat)
print('validation accuracy: %f' % (np.mean(y_val == y_val_pred), ))
# Out:
# training accuracy: 0.303600
# validation accuracy: 0.298700

# %% [markdown]
# 2.8 С помощью кросс-валидации выберите значения параметров скорости обучения и регуляризации. В кросс-валидации используйте обучающую и валидационную выборки. Оцените accuracy на тестовой выборке.

# %%
learning_rates = [1e-7, 5e-5]
regularization_strengths = [2.5e4, 5e4]

# Параметры для кросс-валидации
num_folds = 5
kf = KFold(n_splits=num_folds)

# Инициализация переменных для сохранения результатов
results_kfold_dev = {}
best_val_kfold_dev = -1
best_svm_kfold_dev = None
best_params_kfold_dev = {'lr': 0, 'reg': 0}

# Перебор комбинаций параметров
for lr in learning_rates:
    for reg in regularization_strengths:
        val_accuracies_dev = []
        for train_index, val_index in kf.split(X_dev):
            X_train_kfold_dev, X_val_kfold_dev = X_dev[train_index], X_dev[val_index]
            y_train_kfold_dev, y_val_kfold_dev = y_dev[train_index], y_dev[val_index]

            svm_dev = LinearSVM()
            svm_dev.train(X_train_kfold_dev, y_train_kfold_dev, learning_rate=lr, reg=reg, num_iters=1000)

            y_val_pred_kfold_dev = svm_dev.predict(X_val_kfold_dev)
            val_accuracy_dev = np.mean(y_val_pred_kfold_dev == y_val_kfold_dev)
            val_accuracies_dev.append(val_accuracy_dev)

        avg_val_accuracy_dev = np.mean(val_accuracies_dev)
        results_kfold_dev[(lr, reg)] = avg_val_accuracy_dev

        if avg_val_accuracy_dev > best_val_kfold_dev:
            best_val_kfold_dev = avg_val_accuracy_dev
            best_svm_kfold_dev = svm_dev
            best_params_kfold_dev['lr'] = lr
            best_params_kfold_dev['reg'] = reg

# Вывод результатов для разработочного подмножества
for (lr, reg), accuracy in sorted(results_kfold_dev.items(), key=lambda x: x[1], reverse=True):
    print(f'Разраб. набор - скорость обучения {lr:e} регуляризация {reg:e} точность: {accuracy:.3f}')

print(f'Лучшая точность валидации на разраб. наборе с KFold: {best_val_kfold_dev:.3f}')
print(f'Лучшая скорость обучения на разраб. наборе: {best_params_kfold_dev["lr"]}')
print(f'Лучшая сила регуляризации на разраб. наборе: {best_params_kfold_dev["reg"]}')

# Окончательное тестирование лучшей модели на тестовой выборке
y_test_pred_kfold_dev = best_svm_kfold_dev.predict(X_test_flat)
test_accuracy_kfold_dev = np.mean(y_test == y_test_pred_kfold_dev)
print(f'Точность линейного SVM на сырых пикселях тестового набора с KFold на разраб. наборе: {test_accuracy_kfold_dev:.3f}')
# Out:
# D:\Лабы\NN\neural-networks-course\Lab1-2\scripts\classifiers\linear_svm.py:90: RuntimeWarning: overflow encountered in double_scalars
#   margins = np.maximum(0, scores - correct_class_scores + 1)
# C:\Users\Maxim\AppData\Local\Programs\Python\Python39\lib\site-packages\numpy\core\fromnumeric.py:86: RuntimeWarning: overflow encountered in reduce
#   return ufunc.reduce(obj, axis, dtype, out, **passkwargs)
# D:\Лабы\NN\neural-networks-course\Lab1-2\scripts\classifiers\linear_svm.py:90: RuntimeWarning: overflow encountered in multiply
#   margins = np.maximum(0, scores - correct_class_scores + 1)
# D:\Лабы\NN\neural-networks-course\Lab1-2\scripts\classifiers\linear_svm.py:111: RuntimeWarning: overflow encountered in multiply
#   binary[np.arange(num_train), y] = -row_sum
# Разраб. набор - скорость обучения 1.000000e-07 регуляризация 5.000000e+04 точность: 0.320
# Разраб. набор - скорость обучения 1.000000e-07 регуляризация 2.500000e+04 точность: 0.300
# Разраб. набор - скорость обучения 5.000000e-05 регуляризация 5.000000e+04 точность: 0.106
# Разраб. набор - скорость обучения 5.000000e-05 регуляризация 2.500000e+04 точность: 0.056
# Лучшая точность валидации на разраб. наборе с KFold: 0.320
# Лучшая скорость обучения на разраб. наборе: 1e-07
# Лучшая сила регуляризации на разраб. наборе: 50000.0
# Точность линейного SVM на сырых пикселях тестового набора с KFold на разраб. наборе: 0.280

# %% [markdown]
# 2.9 Сделайте выводы по второй части задания

# %% [markdown]
# Вторая часть задания фокусируется на более сложных аспектах машинного обучения, включая использование сверточных нейронных сетей (CNN) и методов повышения эффективности обучения, таких как регуляризация, нормализация по батчам и применение dropout. Освещены практические аспекты построения и тренировки CNN.
#
# Основные выводы:
#
# Сверточные нейронные сети существенно повышают точность распознавания изображений благодаря использованию свёрток, которые оптимально работают с пространственными данными.
# Методы, такие как регуляризация и нормализация по батчам, эффективно помогают справиться с переобучением и способствуют улучшению обобщающей способности моделей.
# Dropout — это мощный инструмент регуляризации, который помогает предотвратить избыточное влияние отдельных признаков на процесс обучения модели.

# %% [markdown]
# ## 3.  Построение softmax-классификатора

# %% [markdown]
# 3.1 Разделите данные на обучающую, тестовую и валидационную выборки. Преобразуйте каждое изображение в одномерный массив. Выведите размеры выборок.

# %% [markdown]
# 3.2 Проведите предварительную обработку данных, путем вычитания среднего изображения, рассчитанного  по обучающей выборке.
#
# 3.3 Чтобы далее не учитывать смещение (свободный член b), добавьте дополнитульную размерность к массиву данных и заполните ее единицами.

# %%
mean_image = np.mean(X_train, axis=0)
print(mean_image[:10]) 
plt.figure(figsize=(4,4))
plt.imshow(mean_image.reshape((32,32,3)).astype('uint8')) 
plt.show()


X_train -= mean_image
X_val -= mean_image
X_test -= mean_image



X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])


print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# [[[130.71074 136.05614 132.5538 ]
#   [130.14036 135.44238 131.85358]
#   [131.05044 136.24616 132.58144]
#   [131.56886 136.67804 132.8775 ]
#   [132.1847  137.22858 133.26738]
#   [132.85184 137.8545  133.78034]
#   [133.37154 138.28386 134.15504]
#   [133.89092 138.74072 134.5227 ]
#   [134.48504 139.27524 135.01422]
#   [134.9326  139.6326  135.29142]
#   [135.23398 139.94098 135.51004]
#   [135.40374 140.0906  135.659  ]
#   [135.62016 140.26882 135.81572]
#   [135.63418 140.26172 135.80778]
#   [135.63402 140.22544 135.7769 ]
#   [135.61138 140.17206 135.71862]
#   [135.53046 140.09332 135.58066]
#   [135.5036  140.06138 135.55468]
#   [135.49102 140.05346 135.5742 ]
#   [135.38346 139.96092 135.47278]
#   [135.10962 139.71384 135.20938]
#   [134.9583  139.6188  135.177  ]
#   [134.8102  139.49842 135.10764]
#   [134.52658 139.29726 134.92798]
#   [134.04618 138.94646 134.62446]
#   [133.6069  138.58728 134.33616]
#   [133.0759  138.10716 133.93838]
#   [132.32476 137.4154  133.3761 ]
#   [131.58878 136.7739  132.84264]
#   [131.05902 136.307   132.44078]
#   [130.39308 135.70848 132.00036]
#   [130.174   135.4736  131.89246]]
#
#  [[130.0993  135.29484 131.36412]
#   [129.3446  134.45914 130.4656 ]
#   [128.93242 126.27988 119.0879 ]
#   [129.10684 126.25116 119.12086]
#   [129.25286 126.27972 119.21704]
#   [129.3737  126.378   119.33604]
#   [129.5096  126.58832 119.55084]
#   [129.60204 126.75692 119.70606]
#   [129.59876 126.86692 119.76288]
#   [129.42442 126.84826 119.71014]
#   [129.01668 126.66094 119.5022 ]
#   [128.7837  126.651   119.44946]
#   [128.6435  126.87354 119.61558]
#   [128.49028 127.1366  119.84044]
#   [128.17928 127.32562 119.98778]
#   [127.89364 127.60528 120.25848]
#   [127.58724 127.89012 120.50522]
#   [127.23842 128.11868 120.7386 ]
#   [126.76966 128.17478 120.7836 ]
#   [126.27504 128.3042  120.92644]
#   [125.97282 128.55654 121.3336 ]
#   [126.4166  129.33416 122.23266]]
#
#  [[127.22844 129.92706 122.42308]
#   [125.68746 127.94512 120.30852]
#   [125.81298 127.47388 119.76716]
#   [125.85342 126.90016 119.15446]
#   [126.068   126.5498  118.7329 ]
#   [126.41196 126.23094 118.38984]
#   [126.8012  125.91292 118.14306]
#   [126.85884 125.27852 117.58998]
#   [127.21956 124.98364 117.37084]
#   [127.75622 124.9722  117.38032]
#   [128.1443  124.91906 117.31304]
#   [128.46076 124.94468 117.44466]
#   [128.74824 124.95918 117.52374]
#   [128.94578 124.8874  117.52588]
#   [129.07996 124.84332 117.54042]
#   [129.19524 124.9111  117.64586]
#   [129.36068 125.17706 117.92262]
#   [129.3598  125.3049  118.07452]
#   [129.45744 125.53722 118.27526]
#   [129.36636 125.61576 118.26738]
#   [128.9068  125.46946 118.0265 ]
#   [128.5037  125.41428 117.90988]
#   [128.1774  125.50178 117.94632]
#   [128.01422 125.80468 118.18458]
#   [127.82222 126.2303  118.53594]
#   [127.63718 126.6687  118.92462]
#   [127.27772 126.94152 119.1286 ]
#   [126.92268 127.20776 119.39566]
#   [126.38504 127.23238 119.42434]
#   [125.86472 127.41692 119.64022]
#   [125.562   127.769   120.09916]
#   [126.12176 128.68086 121.14128]]]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 9
#       5 plt.show()
#       8 X_train -= mean_image
# ----> 9 X_val -= mean_image
#      10 X_test -= mean_image
#      14 X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
#
# NameError: name 'X_val' is not defined

# %% [markdown]
# 3.4 Реализуйте функции в classifiers/softmax.py

# %%
from scripts.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print('loss: %f' % loss)
print('sanity check: %f' % (-np.log(0.1)))

# %% [markdown]
# 3.5 Убедитесь, что вы верно реализовали расчет градиента, сравнив с реализацией численными методами (код приведен ниже).

# %%
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)


from scripts.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)


loss, grad = softmax_loss_naive(W, X_dev, y_dev, 5e1)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 5e1)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# %% [markdown]
# 3.6 Сравните softmax_loss_naive и softmax_loss_vectorized реализации

# %%
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('naive loss: %e computed in %fs' % (loss_naive, toc - tic))

from scripts.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.000005)
toc = time.time()
print('vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic))


grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print('Loss difference: %f' % np.abs(loss_naive - loss_vectorized))
print('Gradient difference: %f' % grad_difference)

# %% [markdown]
# 3.7 Реализуйте стохастический градиентный спуск в /classifiers/linear_classifier.py . Реализуйте методы train() и predict() и запустите следующий код
#
# 3.8 Обучите Softmax-классификатор и оцените accuracy на тестовой выборке.

# %% [markdown]
# 3.9 С помощью кросс-валидации выберите значения параметров скорости обучения и регуляризации. В кросс-валидации используйте обучающую и валидационную выборки. Оцените accuracy на тестовой выборке.

# %%
learning_rates = [1e-7, 5e-5]
regularization_strengths = [2.5e4, 5e4]

# %% [markdown]
# 3.10 Сделайте выводы по третьей части задания
